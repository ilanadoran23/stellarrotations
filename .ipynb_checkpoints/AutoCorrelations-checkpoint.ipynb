# %% [markdown]
# # Autocorrelation Functions

# %%
#tools
from tqdm import tqdm
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
import astropy.stats as astat
import lightkurve as lk
from solartwins import *
import eleanor
import pickle
import eleanor
from IPython.display import Image
import lightkurve as lk
from starspot import sigma_clipping
import starspot as ss
from lightkurve import search_targetpixelfile
from IPython.display import display, HTML
import starspot.rotation_tools as rt

# %%
from matplotlib import rc
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
rc('text', usetex=False)

# %% [markdown]
# # Opening saved files

# %%
#list of stars, target num, sector in tess with two minute cadences
with open('two_result.data', 'rb') as filehandle:
    search_result_two = pickle.load(filehandle)

#stars, target num, sector with thirty minute cadences
with open('thirty_result.data', 'rb') as filehandle:
    search_result_thirty = pickle.load(filehandle)

#names of stars with thirty minute cadences
with open('thirty_m_cadence.data', 'rb') as filehandle:
    thirty_m_cadence = pickle.load(filehandle)
    
#names of stars with two minute cadences
with open('two_m_cadence.data', 'rb') as filehandle:
    two_m_cadence = pickle.load(filehandle)

# %%
# opening young stars and ages data from AutoCorrelations

with open('young_stars_dict.data', 'rb') as filehandle:
    young_stars = pickle.load(filehandle) #list of two min cadence target names and sectors
    
with open('young_star_names.data', 'rb') as filehandle:
    young_star_names = pickle.load(filehandle) #list of two min cadence target names and sectors

# %% [markdown]
# # McQuillan Autocorrelation Function

# %%
# importing data from McQuillan et al 2012
with open('McQuillan_Supplementary_Data/table5.txt', 'r') as f:
    no_rotation_period_txt = f.readlines()
with open('McQuillan_Supplementary_Data/table2.txt', 'r') as f:
    m_dwarf_rotation_period_txt = f.readlines()
with open('McQuillan_Supplementary_Data/table3.txt', 'r') as f:
    giants_txt = f.readlines()
with open('McQuillan_Supplementary_Data/table4.txt', 'r') as f:
    two_periods_txt = f.readlines()

# %%
#converting txt files to DataFrames 
m_dwarf_rotation_period = pd.DataFrame([sub.split(",") for sub in m_dwarf_rotation_period_txt])
giants = pd.DataFrame([sub.split(",") for sub in giants_txt])
two_periods = pd.DataFrame([sub.split(",") for sub in two_periods_txt])
no_rotation_period = pd.DataFrame([sub.split(",") for sub in no_rotation_period_txt])

# %%
#McQuillan et al Autocorrelation Function with the number of points fixed at 100

def ac_mcquillan_set_k(star): 
    varied_k = [] #array of autocorrelated fluxes for a given star with varied lag times
    flux = star.flux[0:] 
    N = len(flux) 
    time = star.time[0:]
    dt = time[1] - time[0] #cadence
    k = np.linspace(5, N/2, 100, dtype = int) #lag time
    flux_bar = np.average(flux)
    
    #equation for McQuillan's AC function
    for i, v in enumerate(k): 
        numerator = []
        for ii in range(N - k[i]): 
            num = (flux[ii]-flux_bar)*(flux[ii + k[i]] - flux_bar)  
            numerator.append(num)
            
        denominator = []
        for jj in range(N):
            den = (flux[jj]-flux_bar)**2
            denominator.append(den)
            
        rk = (np.sum(numerator)/np.sum(denominator))
        varied_k.append(rk)
    
    tau = k * dt 

    return varied_k, tau

# %%
#McQuillan function with adjustable resolution 
def ac_mcquillan(star, num_points): 
    varied_k = [] #array of autocorrelated fluxes for a given star with varied lag time 
    flux = star.flux[0:] 
    N = len(flux)
    time = star.time[0:]
    dt = time[1] - time[0] #cadence
    k = np.linspace(5, N/2, num_points, dtype = int) #lag time
    flux_bar = np.average(flux)
    
    
    #equation for McQuillan's AC function
    for i, v in enumerate(k): 
        numerator = []
        for ii in range(N - k[i]): 
            num = (flux[ii]-flux_bar)*(flux[ii + k[i]] - flux_bar)  
            numerator.append(num)
            
        denominator = []
        for jj in range(N):
            den = (flux[jj]-flux_bar)**2
            denominator.append(den)
            
        rk = (np.sum(numerator)/np.sum(denominator))
        varied_k.append(rk)
    
    tau = k * dt

    return varied_k, tau

# %% [markdown]
# # Errors in Periods

# %%
# McQuillan : σ = (1.483 × MAD)/ √N-1

def period_error(star, num_points):
    varied_k = [] #array of autocorrelated fluxes for a given star with varied lag  
    flux = star.flux[0:] 
    N = len(flux)
    time = star.time[0:]
    dt = time[1] - time[0] #cadence
    k = np.linspace(5, N/2, num_points, dtype = int) #lag 
    flux_bar = np.average(flux)
    
    for i, v in enumerate(k): 
        numerator = []
        for ii in range(N - k[i]): 
            num = (flux[ii]-flux_bar)*(flux[ii + k[i]] - flux_bar)  
            numerator.append(num)
            
        denominator = []
        for jj in range(N):
            den = (flux[jj]-flux_bar)**2
            denominator.append(den)
            
        rk = (np.sum(numerator)/np.sum(denominator))
        varied_k.append(rk)
    
    tau = k * dt         
    mad_tau = astat.median_absolute_deviation(tau) 
    
    error = (1.483 * mad_tau)/(np.sqrt(N - 1))
    
    return error

# %%
period_error(young_star_names[0], 100)
# Out:
# 0.033594732921313146

# %% [markdown]
# # Finding Peaks

# %%
def find_peaks(y): #finding peak positions in a given array
    peaks = []
    for index, value in enumerate(y):
        if value > y[np.int(index - 1)] or value == y[np.int(index - 1)]:
            if index == len(y)-1:
                break
            if value > y[np.int(index + 1)] or value == y[np.int(index + 1)]:
                peaks.append(value)  
    return(peaks)

# %%
ac_3 = ac_mcquillan(young_star_names[0], 100)
ac_3
# Out:
# ([nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  array([6.94447918e-03, 1.23611729e-01, 2.40278980e-01, 3.56946230e-01,
#         4.75002376e-01, 5.91669626e-01, 7.08336876e-01, 8.26393022e-01,
#         9.43060273e-01, 1.05972752e+00, 1.17778367e+00, 1.29445092e+00,
#         1.41111817e+00, 1.52917432e+00, 1.64584157e+00, 1.76250882e+00,
#         1.88056496e+00, 1.99723221e+00, 2.11389946e+00, 2.23195561e+00,
#         2.34862286e+00, 2.46529011e+00, 2.58334626e+00, 2.70001351e+00,
#         2.81668076e+00, 2.93334801e+00, 3.05140415e+00, 3.16807140e+00,
#         3.28473865e+00, 3.40279480e+00, 3.51946205e+00, 3.63612930e+00,
#         3.75418544e+00, 3.87085270e+00, 3.98751995e+00, 4.10557609e+00,
#         4.22224334e+00, 4.33891059e+00, 4.45696674e+00, 4.57363399e+00,
#         4.69030124e+00, 4.80835738e+00, 4.92502463e+00, 5.04169188e+00,
#         5.15974803e+00, 5.27641528e+00, 5.39308253e+00, 5.50974978e+00,
#         5.62780593e+00, 5.74447318e+00, 5.86114043e+00, 5.97919657e+00,
#         6.09586382e+00, 6.21253107e+00, 6.33058722e+00, 6.44725447e+00,
#         6.56392172e+00, 6.68197787e+00, 6.79864512e+00, 6.91531237e+00,
#         7.03336851e+00, 7.15003576e+00, 7.26670301e+00, 7.38475916e+00,
#         7.50142641e+00, 7.61809366e+00, 7.73614981e+00, 7.85281706e+00,
#         7.96948431e+00, 8.08615156e+00, 8.20420770e+00, 8.32087495e+00,
#         8.43754220e+00, 8.55559835e+00, 8.67226560e+00, 8.78893285e+00,
#         8.90698900e+00, 9.02365625e+00, 9.14032350e+00, 9.25837964e+00,
#         9.37504689e+00, 9.49171414e+00, 9.60977029e+00, 9.72643754e+00,
#         9.84310479e+00, 9.96116094e+00, 1.00778282e+01, 1.01944954e+01,
#         1.03125516e+01, 1.04292188e+01, 1.05458861e+01, 1.06625533e+01,
#         1.07806095e+01, 1.08972767e+01, 1.10139440e+01, 1.11320001e+01,
#         1.12486674e+01, 1.13653346e+01, 1.14833908e+01, 1.16000580e+01]))

# %%
plt.scatter(ac_3[1], ac_3[0])
plt.xlabel('tau', fontsize = 20)
plt.ylabel('AC', fontsize = 20)
plt.title('Autocorrelated Star 3', fontsize = 25)
# Out:
# Text(0.5, 1.0, 'Autocorrelated Star 3')

# %%
acs = ac_3[0]
peaks = []
for index, value in enumerate(acs):
    if value > acs[np.int(index - 1)]:
        if index == 99:
            break
        if value > acs[np.int(index + 1)]:
            peaks.append(value)

# %%
peaks
# Out:
# []

# %%
# comparing to scipy's similar function
print(acs[scipy.signal.find_peaks(acs)[0][0]])
print(acs[scipy.signal.find_peaks(acs)[0][1]])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-47575ebdbd2f> in <module>
#       1 # comparing to scipy's similar function
# ----> 2 print(acs[scipy.signal.find_peaks(acs)[0][0]])
#       3 print(acs[scipy.signal.find_peaks(acs)[0][1]])
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
ac_th_5 = ac_mcquillan_set_k(young_star_names[9])
plt.scatter(ac_th_5[1], ac_th_5[0])
plt.xlabel('tau', fontsize = 20)
plt.ylabel('AC', fontsize = 20)
plt.title('Autocorrelated Star 5 (30m cadence)', fontsize = 25)
# Out:
# Text(0.5, 1.0, 'Autocorrelated Star 5 (30m cadence)')

# %%
peaks_5 = []
acs_5 = ac_th_5[0]
for index, value in enumerate(acs_5):
    if value > acs_5[np.int(index - 1)] or value == acs_5[np.int(index - 1)]:
        if index == 99:
            break
        if value > acs_5[np.int(index + 1)] or value == acs_5[np.int(index + 1)]:
            peaks_5.append(value)

# %%
peaks_5
# Out:
# [0.9650247406552669, 0.16989656184026308]

# %%
scipy.signal.find_peaks(acs_5)
acs_5[44]
# Out:
# 0.16989656184026308

# %% [markdown]
# # Error in Peaks

# %% [markdown]
# # Starspot Autocorrelation

# %%
#using starspot toolkit to get ACs for stars

#testing with one of our young stars 
star3 = search_result_two[3].download(quality_bitmask='default')
target_mask_3 = star3.create_threshold_mask(threshold=40, reference_pixel= 'center')
star3.plot(aperture_mask=target_mask_3, mask_color='r');

lc3 = star3.to_lightcurve()
lc3.errorbar()

lc_3 = lc3[(lc3.time < 1347) | (lc3.time > 1350)].bin(binsize=10)

# %%
med = np.median(lc_3.flux)
x = lc_3.time[0:] #time data
y = lc_3.flux[0:]/med - 1 #flux data
yerr = lc_3.flux_err[0:]/med #error in flux

# %%
star3_mask = astat.sigma_clip(y, sigma=1, masked = True) #mask for removing outliers 
flux3 = y[~star3_mask.mask] #clipped flux
time3 = x[~star3_mask.mask] #clipped time
flux_err3 = yerr[~star3_mask.mask] #clipped flux error

# %%
rotate = ss.RotationModel(time3, flux3, flux_err3)

# %%
rotate.lc_plot()
ls_period = rotate.ls_rotation()
ls_period
rotate.ls_plot();

# %%
tess_cadence = 1./24./30.  # This is a TESS 2 minute cadence star.
print(tess_cadence)
print(type(tess_cadence))

#dt =float(time3[1] - time3[0])
#print(dt)
#print(type(dt))
#acf_period = rotate.acf_rotation(dt)

acf_period = rotate.acf_rotation(tess_cadence)
acf_period
# Out:
# 0.0013888888888888887
# <class 'float'>
# 2.4777777777777774

# %%
rotate.acf_plot();

# %%
period_grid = np.linspace(.1, 2, 1000)
pdm_period, period_err = rotate.pdm_rotation(period_grid, pdm_nbins=10)  
print(pdm_period, period_err)
# Out:
# 100%|██████████| 1000/1000 [00:00<00:00, 1914.72it/s]
# fitting to a limited range
# 2.0 0.33733922617365486

# %%
rotate.pdm_plot();

# %%
# Autocorrelation function
ACF_array = rotate.acf
lag_array = rotate.lags

ACF_array
# Out:
# array([ 0.94956633,  0.94941043,  0.94916466, ..., -0.07380434,
#        -0.0736096 , -0.07341486])

# %%
acf_peak_positions, acf_peak_heights = rt.get_peak_statistics(rotate.lags, rotate.acf, sort_by="height")
print(acf_peak_positions[0])
# Out:
# 2.4777777777777774

# %% [markdown]
# # Testing Functions

# %%
# mcquillan function

# %%
time = young_star_names[0].time[0:]
test_flux = np.abs(188000 * np.sin((np.pi)/4 * time))

plt.plot(time, test_flux)

# %%
#altered for test
def test_ac_mcquillan(flux, num_points): 
    varied_k = [] #array of autocorrelated fluxes for a given star with varied lag  
    N = len(flux)
    time = young_star_names[0].time[0:]
    dt = time[1] - time[0]
    k = np.linspace(5, N/2, num_points, dtype = int) #lag 
    flux_bar = np.average(flux)
    
    for i, v in enumerate(k): 
        numerator = []
        for ii in range(N - k[i]): 
            num = (flux[ii]-flux_bar)*(flux[ii + k[i]] - flux_bar)  
            numerator.append(num)
            
        denominator = []
        for jj in range(N):
            den = (flux[jj]-flux_bar)**2
            denominator.append(den)
            
        rk = (np.sum(numerator)/np.sum(denominator))
        varied_k.append(rk)
    
    tau = k * dt
    return varied_k, tau

# %%
test = test_ac_mcquillan(test_flux, 10) #test with 10 points

plt.scatter(test[1], test[0])
plt.xlabel('tau', fontsize = 20)
plt.ylabel('AC', fontsize = 20)
plt.title('Autocorrelated Star 1', fontsize = 25)
# Out:
# Text(0.5, 1.0, 'Autocorrelated Star 1')

# %%
test2 = test_ac_mcquillan(test_flux, 100) #test with 100 points

plt.plot(test2[1], test2[0])
plt.xlabel('tau', fontsize = 20)
plt.ylabel('AC', fontsize = 20)
plt.title('Autocorrelated Star 1', fontsize = 25)
# Out:
# Text(0.5, 1.0, 'Autocorrelated Star 1')

# %%
# starspot test

# %%
med = np.median(test_flux)
zer = np.ones_like(test_flux)
yerr_test = (23.29299372 * zer)/med

# %%
test_mask = astat.sigma_clip(test_flux, sigma=1, masked = True)
flux_test = test_flux[~test_mask.mask]
time_test = time[~test_mask.mask]
flux_err_test = yerr_test[~test_mask.mask]

# %%
rotate_test = ss.RotationModel(time_test, flux_test, flux_err_test)

# %%
rotate_test.lc_plot()
ls_period_test = rotate_test.ls_rotation()
ls_period_test
# Out:
# 4.000014400195843

# %%
tess_cadence = 1./24./30.  # This is a TESS 2 minute cadence star.
acf_period_test = rotate_test.acf_rotation(tess_cadence)
acf_period_test
# Out:
# 4.013888888888888

# %%
rotate_test.acf_plot();

# %%
#mcquillan stars test

# %%
display(HTML(m_dwarf_rotation_period.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>KID</td>
#       <td>Teff</td>
#       <td>logg</td>
#       <td>Mass</td>
#       <td>Period</td>
#       <td>Period_Err</td>
#       <td>Amplitude</td>
#       <td>Flag\n</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1162635</td>
#       <td>3899</td>
#       <td>4.62</td>
#       <td>0.5037</td>
#       <td>15.509</td>
#       <td>0.064</td>
#       <td>10.7</td>
#       <td>NF\n</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1430893</td>
#       <td>3956</td>
#       <td>4.41</td>
#       <td>0.5260</td>
#       <td>17.144</td>
#       <td>0.046</td>
#       <td>10.4</td>
#       <td>NF\n</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1572802</td>
#       <td>3990</td>
#       <td>4.48</td>
#       <td>0.5394</td>
#       <td>0.368</td>
#       <td>0.000</td>
#       <td>74.8</td>
#       <td>PB\n</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1721911</td>
#       <td>3833</td>
#       <td>4.58</td>
#       <td>0.4781</td>
#       <td>28.403</td>
#       <td>0.394</td>
#       <td>3.9</td>
#       <td>NF\n</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>1866535</td>
#       <td>3878</td>
#       <td>4.50</td>
#       <td>0.4955</td>
#       <td>25.052</td>
#       <td>0.136</td>
#       <td>4.0</td>
#       <td>NF\n</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>1866986</td>
#       <td>3832</td>
#       <td>4.52</td>
#       <td>0.4777</td>
#       <td>35.585</td>
#       <td>0.516</td>
#       <td>6.5</td>
#       <td>NF\n</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>1870952</td>
#       <td>3947</td>
#       <td>4.69</td>
#       <td>0.5225</td>
#       <td>24.428</td>
#       <td>0.081</td>
#       <td>7.1</td>
#       <td>NF\n</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>1873543</td>
#       <td>3702</td>
#       <td>4.52</td>
#       <td>0.4282</td>
#       <td>11.351</td>
#       <td>0.051</td>
#       <td>14.0</td>
#       <td>NF\n</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>1996399</td>
#       <td>3802</td>
#       <td>4.49</td>
#       <td>0.4661</td>
#       <td>27.034</td>
#       <td>0.106</td>
#       <td>6.3</td>
#       <td>NF\n</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>2142372</td>
#       <td>3801</td>
#       <td>4.72</td>
#       <td>0.4658</td>
#       <td>18.646</td>
#       <td>0.092</td>
#       <td>7.0</td>
#       <td>NF\n</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>2157356</td>
#       <td>3813</td>
#       <td>4.51</td>
#       <td>0.4704</td>
#       <td>12.924</td>
#       <td>0.101</td>
#       <td>11.7</td>
#       <td>NF\n</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>2162907</td>
#       <td>3924</td>
#       <td>4.61</td>
#       <td>0.5135</td>
#       <td>52.974</td>
#       <td>12.451</td>
#       <td>9.1</td>
#       <td>NF\n</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>2164791</td>
#       <td>0</td>
#       <td>-inf</td>
#       <td>0.0000</td>
#       <td>3.351</td>
#       <td>0.000</td>
#       <td>9.9</td>
#       <td>PB\n</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>2167693</td>
#       <td>3888</td>
#       <td>4.67</td>
#       <td>0.4994</td>
#       <td>17.328</td>
#       <td>0.080</td>
#       <td>5.5</td>
#       <td>NF\n</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>2285598</td>
#       <td>3951</td>
#       <td>4.49</td>
#       <td>0.5241</td>
#       <td>37.506</td>
#       <td>0.140</td>
#       <td>3.3</td>
#       <td>NF\n</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>2300039</td>
#       <td>3644</td>
#       <td>4.29</td>
#       <td>0.4066</td>
#       <td>1.716</td>
#       <td>0.000</td>
#       <td>12.6</td>
#       <td>PB\n</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>2301872</td>
#       <td>3968</td>
#       <td>4.42</td>
#       <td>0.5307</td>
#       <td>22.988</td>
#       <td>0.183</td>
#       <td>1.7</td>
#       <td>NF\n</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>2302851</td>
#       <td>3984</td>
#       <td>4.47</td>
#       <td>0.5371</td>
#       <td>12.178</td>
#       <td>0.025</td>
#       <td>11.6</td>
#       <td>NF\n</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>2302997</td>
#       <td>3939</td>
#       <td>4.47</td>
#       <td>0.5193</td>
#       <td>25.419</td>
#       <td>0.121</td>
#       <td>11.3</td>
#       <td>NF\n</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>2423549</td>
#       <td>3862</td>
#       <td>4.47</td>
#       <td>0.4893</td>
#       <td>40.091</td>
#       <td>10.625</td>
#       <td>7.6</td>
#       <td>NF\n</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>2441562</td>
#       <td>3806</td>
#       <td>4.46</td>
#       <td>0.4677</td>
#       <td>10.084</td>
#       <td>0.005</td>
#       <td>20.7</td>
#       <td>NF\n</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>2441891</td>
#       <td>3850</td>
#       <td>4.56</td>
#       <td>0.4846</td>
#       <td>15.775</td>
#       <td>0.107</td>
#       <td>6.8</td>
#       <td>NF\n</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>2443935</td>
#       <td>3940</td>
#       <td>4.67</td>
#       <td>0.5197</td>
#       <td>34.185</td>
#       <td>0.446</td>
#       <td>9.1</td>
#       <td>NF\n</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>2554730</td>
#       <td>3602</td>
#       <td>4.21</td>
#       <td>0.3911</td>
#       <td>46.017</td>
#       <td>16.905</td>
#       <td>16.1</td>
#       <td>NF\n</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>2556650</td>
#       <td>3853</td>
#       <td>4.73</td>
#       <td>0.4858</td>
#       <td>28.730</td>
#       <td>0.333</td>
#       <td>7.3</td>
#       <td>PL\n</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>2557350</td>
#       <td>3815</td>
#       <td>4.71</td>
#       <td>0.4711</td>
#       <td>18.799</td>
#       <td>0.074</td>
#       <td>8.5</td>
#       <td>NF\n</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>2570277</td>
#       <td>3836</td>
#       <td>4.65</td>
#       <td>0.4792</td>
#       <td>47.386</td>
#       <td>22.945</td>
#       <td>4.8</td>
#       <td>HM\n</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>2570846</td>
#       <td>3865</td>
#       <td>4.61</td>
#       <td>0.4904</td>
#       <td>10.922</td>
#       <td>0.010</td>
#       <td>35.8</td>
#       <td>NF\n</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>2574427</td>
#       <td>3972</td>
#       <td>4.57</td>
#       <td>0.5323</td>
#       <td>13.425</td>
#       <td>0.081</td>
#       <td>5.7</td>
#       <td>NF\n</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>2577743</td>
#       <td>3511</td>
#       <td>4.06</td>
#       <td>0.3583</td>
#       <td>31.754</td>
#       <td>0.254</td>
#       <td>15.3</td>
#       <td>NF\n</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>2581298</td>
#       <td>3868</td>
#       <td>4.59</td>
#       <td>0.4916</td>
#       <td>17.266</td>
#       <td>0.132</td>
#       <td>8.5</td>
#       <td>NF\n</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>2692704</td>
#       <td>3624</td>
#       <td>4.10</td>
#       <td>0.3992</td>
#       <td>14.804</td>
#       <td>0.136</td>
#       <td>27.2</td>
#       <td>NF\n</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>2692708</td>
#       <td>3531</td>
#       <td>4.05</td>
#       <td>0.3654</td>
#       <td>29.997</td>
#       <td>0.136</td>
#       <td>20.1</td>
#       <td>NF\n</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>2692772</td>
#       <td>3904</td>
#       <td>4.45</td>
#       <td>0.5056</td>
#       <td>27.933</td>
#       <td>0.136</td>
#       <td>5.9</td>
#       <td>NF\n</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>2695622</td>
#       <td>3870</td>
#       <td>4.39</td>
#       <td>0.4924</td>
#       <td>15.959</td>
#       <td>0.032</td>
#       <td>12.4</td>
#       <td>NF\n</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>2714000</td>
#       <td>3877</td>
#       <td>4.57</td>
#       <td>0.4951</td>
#       <td>27.156</td>
#       <td>0.045</td>
#       <td>8.0</td>
#       <td>NF\n</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>2718935</td>
#       <td>3898</td>
#       <td>4.48</td>
#       <td>0.5033</td>
#       <td>34.390</td>
#       <td>0.341</td>
#       <td>5.0</td>

# %%
m_dwarf_rotation_period[0][1]
# Out:
# '1162635'

# %%
mq_KID = 'KIC 1162635'

# %%
mq_test = search_targetpixelfile(mq_KID).download(quality_bitmask='default');

lc_mq_test = mq_test.to_lightcurve(aperture_mask=mq_test.pipeline_mask)
lc_mq_test.errorbar()
lc_mq_test.remove_outliers(sigma=5).bin(binsize=10).errorbar();

mq_ac_test = ac_mcquillan_set_k(lc_mq_test)
mq_ac_test
# Out:
# /Users/ilanadoran/opt/anaconda3/lib/python3.7/site-packages/lightkurve/search.py:233: LightkurveWarning: Warning: 17 files available to download. Only the first file has been downloaded. Please use `download_all()` or specify additional criteria (e.g. quarter, campaign, or sector) to limit your search.
#   LightkurveWarning)
# ([0.9099797251224251,
#   0.8849162115247022,
#   0.860807255006793,
#   0.8261719810510197,
#   0.7942264796568456,
#   0.7577057669036094,
#   0.7189666936672597,
#   0.6761866760941316,
#   0.6353728135421274,
#   0.5905507959823593,
#   0.5487014506104014,
#   0.503506022305353,
#   0.45619081102071446,
#   0.40666624846157345,
#   0.35499524195084803,
#   0.3044225732038741,
#   0.2590929234042568,
#   0.21538863697735808,
#   0.16961601696132386,
#   0.11510989892624628,
#   0.07555454948643893,
#   0.02987517085109519,
#   -0.01075222203430819,
#   -0.048446462777814406,
#   -0.08033301802000796,
#   -0.12394585050368054,
#   -0.15643714232650138,
#   -0.1864367463241468,
#   -0.21951384622316572,
#   -0.23566099319973258,
#   -0.2646114041428086,
#   -0.291543647598768,
#   -0.3066317149618972,
#   -0.32797264451317887,
#   -0.3366533312846519,
#   -0.3492213344344368,
#   -0.3604661362590326,
#   -0.3677114256306369,
#   -0.3726156564309219,
#   -0.3773019377135871,
#   -0.3813288968253704,
#   -0.3840789839434557,
#   -0.384062694037188,
#   -0.3856554121234714,
#   -0.38106367515210243,
#   -0.38228277297662605,
#   -0.3739708352087684,
#   -0.3714451664296022,
#   -0.3644068007708931,
#   -0.35968275414282924,
#   -0.34235396041241845,
#   -0.3385702237435738,
#   -0.32332347383691445,
#   -0.3106200968519244,
#   -0.29863892317117424,
#   -0.2875458898462909,
#   -0.26163983191651485,
#   -0.24592591264007624,
#   -0.22791179050578708,
#   -0.20816640751325968,
#   -0.1880673345140685,
#   -0.16931156332730193,
#   -0.13869404285300158,
#   -0.12011281198829428,
#   -0.10149454908586597,
#   -0.07947520517452371,
#   -0.05747697004847365,
#   -0.029383821970123663,
#   -0.009123565324430295,
#   0.019454043780633347,
#   0.04710763283274543,
#   0.07507576504683704,
#   0.09685547448494912,
#   0.1231470820210266,
#   0.14567549859801346,
#   0.17110888735042798,
#   0.1956919272819343,
#   0.21593665351859756,
#   0.23322292849848492,
#   0.2622407251792244,
#   0.2791417386379695,
#   0.29277256650826006,
#   0.31039756416131925,
#   0.3146718836665079,
#   0.3229510321053509,
#   0.3261329850664488,
#   0.32759509581743174,
#   0.3273329907017937,
#   0.32298130723661367,
#   0.3158501257775628,
#   0.314567256374644,
#   0.30083028221801444,
#   0.2865111927131349,
#   0.27163313943097106,
#   0.2548956535843407,
#   0.23928091417130348,
#   0.22122457446642996,
#   0.20019226268919685,
#   0.17986972727002354,
#   0.15596356960932273],
#  array([ 0.10217356,  0.26565124,  0.42912893,  0.59260662,  0.75608431,
#          0.919562  ,  1.08303969,  1.26695209,  1.43042977,  1.59390746,
#          1.75738515,  1.92086284,  2.08434053,  2.26825293,  2.43173062,
#          2.5952083 ,  2.75868599,  2.92216368,  3.08564137,  3.26955377,
#          3.43303146,  3.59650915,  3.75998684,  3.92346452,  4.08694221,
#          4.27085461,  4.4343323 ,  4.59780999,  4.76128768,  4.92476537,
#          5.08824305,  5.27215545,  5.43563314,  5.59911083,  5.76258852,
#          5.92606621,  6.0895439 ,  6.25302159,  6.43693398,  6.60041167,
#          6.76388936,  6.92736705,  7.09084474,  7.25432243,  7.43823483,
#          7.60171252,  7.7651902 ,  7.92866789,  8.09214558,  8.25562327,
#          8.43953567,  8.60301336,  8.76649105,  8.92996873,  9.09344642,
#          9.25692411,  9.44083651,  9.6043142 ,  9.76779189,  9.93126958,
#         10.09474727, 10.25822495, 10.44213735, 10.60561504, 10.76909273,
#         10.93257042, 11.09604811, 11.2595258 , 11.42300348, 11.60691588,
#         11.77039357, 11.93387126, 12.09734895, 12.26082664, 12.42430433,
#         12.60821673, 12.77169441, 12.9351721 , 13.09864979, 13.26212748,
#         13.42560517, 13.60951757, 13.77299526, 13.93647294, 14.09995063,
#         14.26342832, 14.42690601, 14.61081841, 14.7742961 , 14.93777379,
#         15.10125148, 15.26472916, 15.42820685, 15.61211925, 15.77559694,
#         15.93907463, 16.10255232, 16.26603001, 16.42950769, 16.61342009]))

# %%
plt.scatter(mq_ac_test[1], mq_ac_test[0])
plt.xlabel('tau', fontsize = 20)
plt.ylabel('AC', fontsize = 20)
plt.title('Autocorrelated Star 1', fontsize = 25)
# Out:
# Text(0.5, 1.0, 'Autocorrelated Star 1')

# %%
med_mq_test = np.median(lc_mq_test.flux)
time_mq_test = lc_mq_test.time[0:]
flux_mq_test = lc_mq_test.flux[0:]/med_mq_test - 1
yerr_mq_test = lc_mq_test.flux_err[0:]/med_mq_test

# %%
mq_test_mask = astat.sigma_clip(flux_mq_test, sigma=1, masked = True)
flux_mq_test = flux_mq_test[~mq_test_mask.mask]
time_mq_test = time_mq_test[~mq_test_mask.mask]
flux_err_mq_test = yerr_mq_test[~mq_test_mask.mask]

# %%
rotate_mq_test = ss.RotationModel(time_mq_test, flux_mq_test, flux_err_mq_test)

# %%
rotate_mq_test.lc_plot()
ls_period_mq_test = rotate_mq_test.ls_rotation()
ls_period_mq_test

acf_period_mq_test = rotate_mq_test.acf_rotation(tess_cadence)
acf_period_mq_test

rotate_mq_test.acf_plot();

# %%
mq_KID_2 = 'KIC 3934090'
mq_test2 = search_targetpixelfile(mq_KID_2).download(quality_bitmask='default');
# Out:
# /Users/ilanadoran/opt/anaconda3/lib/python3.7/site-packages/lightkurve/search.py:233: LightkurveWarning: Warning: 17 files available to download. Only the first file has been downloaded. Please use `download_all()` or specify additional criteria (e.g. quarter, campaign, or sector) to limit your search.
#   LightkurveWarning)

# %%
lc_mq_test2 = mq_test2.to_lightcurve(aperture_mask=mq_test2.pipeline_mask)
lc_mq_test2.errorbar()
lc_mq_test2.remove_outliers(sigma=5).bin(binsize=10).errorbar();

mq_ac_test2 =ac_mcquillan_set_k(lc_mq_test2)
mq_ac_test2
# Out:
# ([0.7768449179414624,
#   0.7605727950432458,
#   0.7371753999725367,
#   0.716632471022893,
#   0.6932936774973818,
#   0.6544168531935198,
#   0.6109378852745269,
#   0.5641405902956896,
#   0.5204624586758697,
#   0.4791082919125843,
#   0.43437116745884113,
#   0.41101929635192147,
#   0.3539773910854754,
#   0.3166736046807451,
#   0.2850278964933367,
#   0.25836361090792226,
#   0.23944281175822094,
#   0.2257043610353388,
#   0.21318819815788714,
#   0.21094923758050788,
#   0.20879159684119655,
#   0.21740963561134677,
#   0.22905794513815636,
#   0.2445633256520106,
#   0.2743738909178039,
#   0.295711814487815,
#   0.32332659849569023,
#   0.3820043082268255,
#   0.37428923422020816,
#   0.399161512514444,
#   0.4245529911788087,
#   0.4401190703110489,
#   0.456648521565043,
#   0.4646399432162123,
#   0.4749116989511992,
#   0.4642522176845644,
#   0.45547037419761827,
#   0.44307917649395984,
#   0.4178009106557306,
#   0.3884898565729122,
#   0.3581102563227585,
#   0.3261741617508451,
#   0.29254869996989913,
#   0.2552733405572729,
#   0.2173174226431078,
#   0.1778515246555335,
#   0.13953051212454098,
#   0.10863253431422452,
#   0.07848411453853542,
#   0.04642778777051009,
#   0.015299546955248816,
#   -0.004675419211516933,
#   -0.020570269177257065,
#   -0.03348732436619066,
#   -0.04375912014945021,
#   -0.03642122077500361,
#   -0.04434456400335628,
#   -0.03849162909489743,
#   -0.02812977930937196,
#   -0.014343343474306079,
#   0.003340319022677836,
#   0.018639683940323528,
#   0.036391126318454994,
#   0.06427614514816925,
#   0.06899202585773277,
#   0.08229292371623963,
#   0.09476796065839328,
#   0.1014077021358309,
#   0.10571439143958601,
#   0.10565568067182614,
#   0.10391494973269576,
#   0.09883811030064782,
#   0.08573608488280292,
#   0.06790870551852787,
#   0.05396372585339634,
#   0.03108846923973053,
#   0.007814892505914937,
#   -0.017196730112384952,
#   -0.04402181861451984,
#   -0.06793995773423236,
#   -0.09594543812743854,
#   -0.12720272175880304,
#   -0.14925330070053594,
#   -0.17173964853813353,
#   -0.1970153367239025,
#   -0.21401862457732673,
#   -0.19486352118789121,
#   -0.24052878984643147,
#   -0.2480599039328349,
#   -0.23542530010928603,
#   -0.24748192726140902,
#   -0.23781877420419778,
#   -0.2393653511173392,
#   -0.2278364873841961,
#   -0.21616947895479352,
#   -0.20024998473834235,
#   -0.1809167029429681,
#   -0.16085503772696202,
#   -0.15158716840268047,
#   -0.136948286879701],
#  array([ 0.10217279,  0.26564926,  0.42912572,  0.59260219,  0.75607865,
#          0.91955512,  1.08303159,  1.26694261,  1.43041907,  1.59389554,
#          1.75737201,  1.92084847,  2.08432494,  2.26823596,  2.43171243,
#          2.59518889,  2.75866536,  2.92214182,  3.08561829,  3.26952931,
#          3.43300578,  3.59648224,  3.75995871,  3.92343518,  4.08691164,
#          4.27082267,  4.43429913,  4.5977756 ,  4.76125206,  4.92472853,
#          5.08820499,  5.27211602,  5.43559248,  5.59906895,  5.76254542,
#          5.92602188,  6.08949835,  6.25297481,  6.43688584,  6.6003623 ,
#          6.76383877,  6.92731523,  7.0907917 ,  7.25426816,  7.43817919,
#          7.60165565,  7.76513212,  7.92860859,  8.09208505,  8.25556152,
#          8.43947254,  8.60294901,  8.76642547,  8.92990194,  9.0933784 ,
#          9.25685487,  9.44076589,  9.60424236,  9.76771882,  9.93119529,
#         10.09467176, 10.25814822, 10.44205925, 10.60553571, 10.76901218,
#         10.93248864, 11.09596511, 11.25944157, 11.42291804, 11.60682906,
#         11.77030553, 11.93378199, 12.09725846, 12.26073493, 12.42421139,
#         12.60812242, 12.77159888, 12.93507535, 13.09855181, 13.26202828,
#         13.42550474, 13.60941577, 13.77289223, 13.9363687 , 14.09984516,
#         14.26332163, 14.4267981 , 14.61070912, 14.77418559, 14.93766205,
#         15.10113852, 15.26461498, 15.42809145, 15.61200247, 15.77547894,
#         15.9389554 , 16.10243187, 16.26590833, 16.4293848 , 16.61329582]))

# %%
plt.scatter(mq_ac_test2[1], mq_ac_test2[0])
plt.xlabel('tau', fontsize = 20)
plt.ylabel('AC', fontsize = 20)
plt.title('Autocorrelated Star 1', fontsize = 25)
# Out:
# Text(0.5, 1.0, 'Autocorrelated Star 1')

# %%
med_mq_test2 = np.median(lc_mq_test2.flux)
time_mq_test2 = lc_mq_test2.time[0:]
flux_mq_test2 = lc_mq_test2.flux[0:]/med_mq_test2 - 1
yerr_mq_test2 = lc_mq_test2.flux_err[0:]/med_mq_test2

# %%
mq_test2_mask = astat.sigma_clip(flux_mq_test2, sigma=1, masked = True)
flux_mq_test2 = flux_mq_test2[~mq_test2_mask.mask]
time_mq_test2 = time_mq_test2[~mq_test2_mask.mask]
flux_err_mq_test2 = yerr_mq_test2[~mq_test2_mask.mask]

# %%
rotate_mq_test2 = ss.RotationModel(time_mq_test2, flux_mq_test2, flux_err_mq_test2)

# %%
rotate_mq_test2.lc_plot()
ls_period_mq_test2 = rotate_mq_test2.ls_rotation()
ls_period_mq_test2
# Out:
# 0.5762524453517054

# %%
acf_period_mq_test2 = rotate_mq_test2.acf_rotation(tess_cadence)
acf_period_mq_test2
# Out:
# 6.988888888888888

# %%
rotate_mq_test2.acf_plot();
plt.xlim(0,17)
# Out:
# (0, 17)
